# %% [markdown]
# <a href="https://colab.research.google.com/github/DepartmentOfStatisticsPUE/air-2024/blob/main/notebooks/0_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Zajęcia z analizy inwestycyjnej regionów
#
# W trakcie zajęć będziemy poznawać:
# *   colab
# *  python
# * pandas
#
# $$
# X^2 + Y^2 = 10
# $$

# %%
a=10

# %% [markdown]
# # Zajęcia 2023.10.02

# %% [markdown]
# Wczytujemy bibliotekę pandas i wykorzystujemy jej funkcjonalności

# %%
import pandas as pd
import numpy as np

# %%
pzn=pd.read_excel("rent-poznan.xlsx")
pzn.head()
# Out:
#          id date_activ date_modif date_expire  individual  price  flat_area  \
# 0  19576742 2015-03-24 2020-09-05  2020-10-05        True   1400       30.0
# 1  20292499 2013-07-19 2020-08-30  2020-09-09        True   4600      160.0
# 2  25876297 2014-04-05 2019-09-10  2019-09-30        True   2300       54.0
# 3  30574847 2014-08-10 2020-03-03  2020-03-10        True   1600       49.0
# 4  30774505 2014-08-17 2019-11-15  2019-12-15        True   1200       32.5
#
#    flat_rooms  flat_floor_no  flat_build_year  ...  flat_internet  \
# 0           1            2.0                0  ...          False
# 1           4            4.0             1900  ...           True
# 2           3            1.0             2009  ...           True
# 3           2            5.0                0  ...          False
# 4           1            3.0             2000  ...          False
#
#    flat_television  flat_phone  flat_anti_blinds  flat_anti_doors_windows  \
# ...

# %%
pzn.tail(n=3)
# Out:
#              id date_activ date_modif date_expire  individual  price  \
# 16445  60994208 2020-09-25 2020-09-25  2020-10-25       False    920
# 16446  60994209 2020-09-25 2020-09-25  2020-10-25       False    990
# 16447  60994243 2020-09-25 2020-09-25  2020-10-25        True   1250
#
#        flat_area  flat_rooms  flat_floor_no  flat_build_year  ...  \
# 16445       41.0           1            NaN                0  ...
# 16446       41.0           1            NaN                0  ...
# 16447       32.0           1            NaN                0  ...
#
#        flat_internet  flat_television  flat_phone  flat_anti_blinds  \
# 16445          False            False       False             False
# 16446          False            False       False             False
# 16447          False            False       False             False
#
#        flat_anti_doors_windows  flat_intercom  flat_monitoring  \
# 16445                    False          False            False
# ...

# %%
pzn.shape[0], pzn.shape[1]
# Out:
# (16448, 51)

# %%
pzn.describe()
# Out:
#                  id         price     flat_area    flat_rooms  flat_floor_no  \
# count  1.644800e+04  16448.000000  16448.000000  16448.000000   15775.000000
# mean   5.930432e+07   1762.621170     47.748831      2.007600       4.179778
# std    3.229472e+06    823.028687     30.889242      0.843865       6.235581
# min    1.957674e+07    250.000000      4.200000      1.000000       0.000000
# 25%    5.952112e+07   1350.000000     35.000000      1.000000       2.000000
# 50%    6.011038e+07   1600.000000     45.990000      2.000000       3.000000
# 75%    6.059584e+07   2000.000000     55.000000      2.000000       5.000000
# max    6.099424e+07  45000.000000   2200.000000     11.000000      54.000000
#
#        flat_build_year     flat_rent   flat_deposit  flat_heating  \
# count     16448.000000  16448.000000   16448.000000  12300.000000
# mean       1174.878161    286.429900    1288.780624      0.282439
# std        1385.741710    496.638169    4874.423998      0.816670
# ...

# %%
pzn.price ##
pzn["price"]
pzn[ ["price"] ]
# Out:
#        price
# 0       1400
# 1       4600
# 2       2300
# 3       1600
# 4       1200
# ...      ...
# 16443    930
# 16444    950
# 16445    920
# 16446    990
# 16447   1250
#
# [16448 rows x 1 columns]

# %% [markdown]
# # Zajęcia 2023.10.09
#
# ##  Rozgrzewka:
#
# + proszę załadowac bibliotekę `pandas`
# + proszę wgrać dane `rent-poznan.xlsx`
# + proszę wczytać dane z pliku xlsx i zapisać pod nazwą `pzn`
# + po utworzeniu proszę wybrać kolumnę `flat_build_year` w taki sposób aby wynikiem była ramka danych
# + proszę wybrać kolumnę `flat_area` i utworzyć podsumowanie zawierające statystyki opisowe

# %%
pzn[["flat_build_year"]]
pzn["flat_area"].describe()
pzn.flat_area.describe()
# Out:
# count    16448.000000
# mean        47.748831
# std         30.889242
# min          4.200000
# 25%         35.000000
# 50%         45.990000
# 75%         55.000000
# max       2200.000000
# Name: flat_area, dtype: float64

# %% [markdown]
# ## Plan na dzisiejsze zajęcia:
#
# + wybór wielu kolumn (dwa sposoby)
# + wybór kolumn na podstawie wzorca
# + tworzenie własnej ramki danych (od zera)

# %%
pzn[ ["price", "flat_area"]]
pzn.iloc[:, 0:2]
pzn.iloc[:3, :]
pzn.iloc[:3, :3]
pzn.iloc[[1,2,3], :]
# Out:
#          id date_activ date_modif date_expire  individual  price  flat_area  \
# 1  20292499 2013-07-19 2020-08-30  2020-09-09        True   4600      160.0
# 2  25876297 2014-04-05 2019-09-10  2019-09-30        True   2300       54.0
# 3  30574847 2014-08-10 2020-03-03  2020-03-10        True   1600       49.0
#
#    flat_rooms  flat_floor_no  flat_build_year  ...  flat_internet  \
# 1           4            4.0             1900  ...           True
# 2           3            1.0             2009  ...           True
# 3           2            5.0                0  ...          False
#
#    flat_television  flat_phone  flat_anti_blinds  flat_anti_doors_windows  \
# 1             True        True             False                    False
# 2             True       False              True                     True
# 3            False       False             False                     True
#
#    flat_intercom  flat_monitoring  flat_alarm_sys  flat_closed_area  \
# ...

# %%
pzn.loc[[1, 2, 3], "id":"price"]
pzn.loc[[0, 1, 2, 3], ["id", "price"]]
# Out:
#          id  price
# 0  19576742   1400
# 1  20292499   4600
# 2  25876297   2300
# 3  30574847   1600

# %% [markdown]
# Zadanie 1.
#
# + proszę wybrać kolumny: `id`, `price`, `flat_area` i `flat_rooms`
# + proszę wybrać powyższe kolumny jako zakres tekstowy
# + proszę wybrać powyższe kolumny jako zakres numeryczny

# %%
pzn.loc[:, ["id", "price", "flat_area", "flat_rooms"]]
pzn.loc[:, "id":"flat_rooms"]
pzn.iloc[:, :8] ## 0:(8-1)
# Out:
#              id date_activ date_modif date_expire  individual  price  \
# 0      19576742 2015-03-24 2020-09-05  2020-10-05        True   1400
# 1      20292499 2013-07-19 2020-08-30  2020-09-09        True   4600
# 2      25876297 2014-04-05 2019-09-10  2019-09-30        True   2300
# 3      30574847 2014-08-10 2020-03-03  2020-03-10        True   1600
# 4      30774505 2014-08-17 2019-11-15  2019-12-15        True   1200
# ...         ...        ...        ...         ...         ...    ...
# 16443  60994206 2020-09-25 2020-09-25  2020-10-25       False    930
# 16444  60994207 2020-09-25 2020-09-25  2020-10-25       False    950
# 16445  60994208 2020-09-25 2020-09-25  2020-10-25       False    920
# 16446  60994209 2020-09-25 2020-09-25  2020-10-25       False    990
# 16447  60994243 2020-09-25 2020-09-25  2020-10-25        True   1250
#
#        flat_area  flat_rooms
# 0           30.0           1
# 1          160.0           4
# 2           54.0           3
# ...

# %%
pzn.columns.str.contains("price")
pzn.columns.str.contains("price|area|ind", regex = True)
pzn.columns.str.contains("^price")
pzn.columns.str.contains("e$")
pzn.columns.str.contains("price|ine$")
pzn.columns.str.contains("(price|ine)$")
# Out:
# <ipython-input-50-fcf4881d6e27>:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   pzn.columns.str.contains("(price|ine)$")
# array([False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
pzn.iloc[:, pzn.columns.str.contains("price")]
pzn.iloc[:, pzn.columns.str.contains("price|area|ind")]
pzn.iloc[:, pzn.columns.str.contains("^price")]
pzn.iloc[:, pzn.columns.str.contains("e$")]
pzn.iloc[:, pzn.columns.str.contains("price|ine$")]
pzn.iloc[:, pzn.columns.str.contains("(price|ine)$")]
# Out:
# <ipython-input-51-3f428a029aee>:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   pzn.iloc[:, pzn.columns.str.contains("(price|ine)$")]
#        price  flat_washmachine
# 0       1400              True
# 1       4600              True
# 2       2300              True
# 3       1600              True
# 4       1200              True
# ...      ...               ...
# 16443    930             False
# 16444    950             False
# 16445    920             False
# 16446    990             False
# 16447   1250              True
#
# [16448 rows x 2 columns]

# %% [markdown]
# Zadanie 2
#
# + proszę wybrać kolumny zaczynające się na literę `p`
# + proszę wybrac kolumny zawierające `id`

# %%
pzn.iloc[:, pzn.columns.str.startswith("p")]
pzn.iloc[:, pzn.columns.str.startswith( ("p", "i") )]
#pzn.iloc[:, pzn.columns.str.contains("id")]
# Out:
#              id  individual  price
# 0      19576742        True   1400
# 1      20292499        True   4600
# 2      25876297        True   2300
# 3      30574847        True   1600
# 4      30774505        True   1200
# ...         ...         ...    ...
# 16443  60994206       False    930
# 16444  60994207       False    950
# 16445  60994208       False    920
# 16446  60994209       False    990
# 16447  60994243        True   1250
#
# [16448 rows x 3 columns]

# %%
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
d = {'a': [1, 2, 3],
     'b': ['a', 'b', 'c']}
d
# Out:
# {'a': [1, 2, 3], 'b': ['a', 'b', 'c']}

# %%
df2=pd.DataFrame(d)
df2
# Out:
#    a  b
# 0  1  a
# 1  2  b
# 2  3  c

# %%
mat=np.array(
    [
        [1, 2, 3],
        [4, 5, 6]
    ]
)
mat
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
df3=pd.DataFrame(mat, columns = ["a", "b", "c"])
df3
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# Zadanie 3
#
# + proszę utworzyć następującą ramkę danych
#
# ```python
#   col1
# 0    a
# 1    b
# 2    c
# 3    d
# ```
#
# + proszę utworzyć następującą ramkę danych
#
# ```python
#    col1  col2
# 0     1     3
# 1     2     4
# ```
#
# + proszę utworzyć pustą ramkę danych z następującymi kolumnami: `iteracja`, `model1`, `model2`.

# %%
pd.DataFrame({"col1" : ['a','b','c','d']})
pd.DataFrame(np.array([[1,3], [2,4]]), columns = ['col1','col2'])
pd.DataFrame(columns = ['interacja', 'model1', 'model2'])
# Out:
# Empty DataFrame
# Columns: [interacja, model1, model2]
# Index: []
